# %%
# !nvidia-smi
# Out:
# Thu Nov 20 17:54:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install -q ultralytics==8.3.228
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.2/112.6 GB disk)

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8s.pt")

# %%
import os
print(f"Current directory: {os.getcwd()}")
print(f"Home directory: {os.path.expanduser('~')}")
# Out:
# Current directory: /content
# Home directory: /root

# %%
if os.path.exists('/content'):
    for item in os.listdir('/content'):
        full_path = os.path.join('/content', item)
        print(f"  {full_path} {'(dir)' if os.path.isdir(full_path) else '(file)'}")
# Out:
#   /content/.config (dir)
#   /content/runs (dir)
#   /content/yolov8s.pt (file)

# %%
print("\n=== Google Drive ===")
drive_path = '/content/drive/MyDrive'
if os.path.exists(drive_path):
    print(f"Google Drive monté à: {drive_path}")
    # Lister les premiers éléments
    items = os.listdir(drive_path)[:10]  # Limiter à 10 items
    for item in items:
        full_path = os.path.join(drive_path, item)
        print(f"  {full_path} {'(dir)' if os.path.isdir(full_path) else '(file)'}")
    if len(os.listdir(drive_path)) > 10:
        print(f"  ... et {len(os.listdir(drive_path)) - 10} autres items")
else:
    print("Google Drive non monté. Utilisez:")
    print("  from google.colab import drive")
    print("  drive.mount('/content/drive')")
# Out:
# === Google Drive ===
# Google Drive non monté. Utilisez:
#   from google.colab import drive
#   drive.mount('/content/drive')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     270             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     271         )
# --> 272       raise ValueError('mount failed' + extra_reason)
# ...

# %%
# During the training, to check my GPU use
# !watch -n 1 nvidia-smi  # every second refresh

# %%
model.train(
    data='content\My Drive\PlantDoc-Object-Detection\diseases\diseases\dataset.yaml"',
    epochs=50,
    imgsz=640,
    batch=24,
    name='diseases_model_v0',
    patience=20,
    verbose=True,
    augment=True,
    device=0,
    amp=True,
    cache=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.229 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
